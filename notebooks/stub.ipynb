# %%
import numpy as np
import pandas as pd
import ensembl_rest as er

# %%
y = pd.read_csv('proteome.tab', sep='\t')

# %%
import re

# %%
re_signal = re.compile('\.\.([0-9]+)')

# %%
re_chain = re.compile('CHAIN ([0-9]+)')

# %%
x = x.fillna()

# %%
x = x[x['Signal peptide'].str.contains('SIGNAL')]

# %%
x['signal_end'] = x['Signal peptide'].str.extract(re_signal)

# %%
x['chain_start'] = x['Chain'].str.extract(re_chain)

# %%
x = x.dropna()

# %%
x['signal_end'] = x['signal_end'].astype(int)
# Out:
# C:\Users\Dynev\AppData\Local\Temp\ipykernel_8580\3917742012.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['signal_end'] = x['signal_end'].astype(int)

# %%
x['chain_start'] = x['chain_start'].astype(int)
# Out:
# C:\Users\Dynev\AppData\Local\Temp\ipykernel_8580\4071022381.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['chain_start'] = x['chain_start'].astype(int)

# %%
len(x[x['signal_end'] + 1 == x['chain_start']])
# Out:
# 3204

# %%
3204 / len(y) * 100
# Out:
# 15.728241127092435

# %%
x['signal_end'].mean()
# Out:
# 24.1497722095672

# %%
x.head(50)
# Out:
#           Entry   Entry name    Status  \
# 2        Q02325   PLGB_HUMAN  reviewed
# 3        Q6UXB8   PI16_HUMAN  reviewed
# 7        P23470  PTPRG_HUMAN  reviewed
# 14       B0FP48  UPK3L_HUMAN  reviewed
# 21       Q5DID0  UROL1_HUMAN  reviewed
# 53       Q9UK28  TM59L_HUMAN  reviewed
# 54       Q9NP99  TREM1_HUMAN  reviewed
# 56       P35503   UD13_HUMAN  reviewed
# 58   A0A0A6YYG2  TVB66_HUMAN  reviewed
# 63       Q9GZX9  TWSG1_HUMAN  reviewed
# 65   A0A0B4J249   TVA5_HUMAN  reviewed
# 68       A0A5B6  TVB28_HUMAN  reviewed
# 70   A0A0K0K1B3  TVB30_HUMAN  reviewed
# 92       Q6ZRU5  YQ032_HUMAN  reviewed
# 95       A8MUN3  YQ048_HUMAN  reviewed
# 105      P30926  ACHB4_HUMAN  reviewed
# 131      P61769   B2MG_HUMAN  reviewed
# 134      P22303   ACES_HUMAN  reviewed
# 147      Q9GZZ6  ACH10_HUMAN  reviewed
# 148      Q96KV6  BT2A3_HUMAN  reviewed
# 156      Q9HBW9  AGRL4_HUMAN  reviewed
# 157      Q15582   BGH3_HUMAN  reviewed
# 158      O00253   AGRP_HUMAN  reviewed
# ...
